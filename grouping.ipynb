# %%
import pandas as pd
from glob import glob
import pandas as pd
import numpy as np
import re
import time
import requests
import numpy as np
import pandas as pd
from itertools import chain
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from textblob import TextBlob
from gensim.models import word2vec
from scipy.cluster.hierarchy import ward, dendrogram

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans, AgglomerativeClustering
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
#nltk.download('popular', halt_on_error=False)
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn import metrics
#textblob
from textblob import TextBlob, Word
from sklearn.metrics import silhouette_score

from utils1 import Cleaner,Super_list
# Import Counter
from collections import Counter
import string

# %%
#putting all 7 dfs into one list and dropping rows where all values are NA
allFiles =glob("gr*.csv")
ls=[]
frame = pd.DataFrame()
for i in allFiles:
    ls.append(pd.read_csv(i,index_col=None))
full=pd.concat(ls,sort=True)# concating all dataframe
full.head()
# Out:
#    # of Bubbles # of Obj in Category # of Photos  \
# 0           4.0                   34           4
# 1           5.0                Issue          15
# 2           5.0                Issue          15
# 3           5.0                Issue          15
# 4           5.0                Issue          15
#
#   # of Reviewer's Positive Reviews # of Reviewer's Reviews # of Reviews  \
# 0                               28                     214            1
# 1                                3                       4            9
# 2                            Issue                      21            9
# 3                                3                       4            9
# 4                                2                       5            9
#
#   Avg Review Score  BUB         Bubble Dsitibution     DestID    ...     \
# 0                4  POS  ['0', '1', '0', '0', '0']  d10026996    ...
# 1              4.5  POS  ['7', '0', '2', '0', '0']  d10029890    ...
# ...

# %%
full.drop("Unnamed: 0",inplace=True,axis=1)

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38457 entries, 0 to 1528
# Data columns (total 37 columns):
# # of Bubbles                        38456 non-null float64
# # of Obj in Category                38457 non-null object
# # of Photos                         38457 non-null object
# # of Reviewer's Positive Reviews    38457 non-null object
# # of Reviewer's Reviews             38457 non-null object
# # of Reviews                        38457 non-null object
# Avg Review Score                    38457 non-null object
# BUB                                 38457 non-null object
# Bubble Dsitibution                  38457 non-null object
# DestID                              38457 non-null object
# DestType                            38457 non-null object
# ID                                  38457 non-null int64
# Language Distribution               38457 non-null object
# Link                                38457 non-null object
# ...

# %%
full.to_csv("Cleaned.csv")

# %%
len
# Out:
# 0                                                      []
# 1                                  [('shisha', 'seisha')]
# 2                                  [('shisha', 'seisha')]
# 3                 [('shisha', 'seisha'), ('2end', 'end')]
# 4                  [('couse', 'house'), ('alco', 'also')]
# 5                                                      []
# 6                                                      []
# 7       [("'ve", 'eve'), ('doesnt', 'does'), ("'s", 'i...
# 8                                          [("'s", 'is')]
# 9                               [('martiros', 'martyrs')]
# 10                                         [("'s", 'is')]
# 11      [("'s", 'is'), ("'ve", 'eve'), ("'ve", 'eve'),...
# 12                                       [("'ve", 'eve')]
# 13                                                     []
# 14              [("'s", 'is'), ("'d", 'd'), ("'s", 'is')]
# 15                                                     []
# ...
